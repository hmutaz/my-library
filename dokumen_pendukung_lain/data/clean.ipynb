# %%
import pandas as pd

# %%
df = pd.read_csv('library-collection-inventory.csv', skiprows=[1,25000], nrows=25000)

# %%
df2 = pd.read_csv('Library_Collection_Inventory.csv', nrows=25000)

# %%
df.head(5)
# Out:
#     BibNum                                              Title  \
# 0  2248846  Naruto. Vol. 1, Uzumaki Naruto / story and art...
# 1  3209270  Peace, love & Wi-Fi : a ZITS treasury / by Jer...
# 2  1907265     The Paris pilgrims : a novel / Clancy Carlile.
# 3  1644616  Erotic by nature : a celebration of life, of l...
# 4  1736505  Children of Cambodia's killing fields : memoir...
#
#                       Author                       ISBN PublicationYear  \
# 0  Kishimoto, Masashi, 1974-                 1569319006    2003, c1999.
# 1        Scott, Jerry, 1955-  144945867X, 9781449458676           2014.
# 2     Carlile, Clancy, 1930-                 0786706155          c1999.
# 3                        NaN                 094020813X    1991, c1988.
# 4                        NaN     0300068395, 0300078730          c1997.
#
#                            Publisher  \
# 0                               Viz,
# 1         Andrews McMeel Publishing,
# 2                    Carroll & Graf,
# ...

# %%
df2.head(5)
# Out:
#     BibNum                                              Title  \
# 0  3011076  A tale of two friends / adapted by Ellie O'Rya...
# 1  2248846  Naruto. Vol. 1, Uzumaki Naruto / story and art...
# 2  3209270  Peace, love & Wi-Fi : a ZITS treasury / by Jer...
# 3  1907265     The Paris pilgrims : a novel / Clancy Carlile.
# 4  1644616  Erotic by nature : a celebration of life, of l...
#
#                       Author  \
# 0              O'Ryan, Ellie
# 1  Kishimoto, Masashi, 1974-
# 2        Scott, Jerry, 1955-
# 3     Carlile, Clancy, 1930-
# 4                        NaN
#
#                                                 ISBN PublicationYear  \
# 0  1481425730, 1481425749, 9781481425735, 9781481...           2014.
# 1                                         1569319006    2003, c1999.
# 2                          144945867X, 9781449458676           2014.
# 3                                         0786706155          c1999.
# ...

# %%
len(df2.index)
# Out:
# 25000

# %%
len(df)
# Out:
# 25000

# %%
df2 = df2.append(df)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14140\2824340482.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(df)

# %%
df2.head(5)
# Out:
#     BibNum                                              Title  \
# 0  3011076  A tale of two friends / adapted by Ellie O'Rya...
# 1  2248846  Naruto. Vol. 1, Uzumaki Naruto / story and art...
# 2  3209270  Peace, love & Wi-Fi : a ZITS treasury / by Jer...
# 3  1907265     The Paris pilgrims : a novel / Clancy Carlile.
# 4  1644616  Erotic by nature : a celebration of life, of l...
#
#                       Author  \
# 0              O'Ryan, Ellie
# 1  Kishimoto, Masashi, 1974-
# 2        Scott, Jerry, 1955-
# 3     Carlile, Clancy, 1930-
# 4                        NaN
#
#                                                 ISBN PublicationYear  \
# 0  1481425730, 1481425749, 9781481425735, 9781481...           2014.
# 1                                         1569319006    2003, c1999.
# 2                          144945867X, 9781449458676           2014.
# 3                                         0786706155          c1999.
# ...

# %%
df2.to_csv('seattle_inventory.csv')
